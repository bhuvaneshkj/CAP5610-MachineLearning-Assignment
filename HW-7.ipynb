# %%
import numpy as np
import pandas as pd
from surprise import Dataset
from surprise import Reader
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path=os.path.expanduser(r'C:\Users\chat2\Downloads\restaurant_ratings.txt')
reader=Reader(line_format='user item rating timestamp',sep='\t')
data=Dataset.load_from_file(file_path,reader=reader)

# %%
from surprise import SVD
from surprise import NMF
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise import KNNBasic
from surprise.model_selection import KFold
from surprise import accuracy

# %% [markdown]
# ### Question 5 SVD

# %%
# Use the famous SVD algorithm.
algo = SVD()

# Run 5-fold cross-validation and print results.
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9391  0.9467  0.9478  0.9445  0.0039
# MAE (testset)     0.7403  0.7466  0.7502  0.7457  0.0041
# Fit time          2.94    3.06    3.62    3.21    0.30
# Test time         0.19    0.24    0.15    0.19    0.03
# {'test_rmse': array([0.93907326, 0.94667942, 0.94781547]),
#  'test_mae': array([0.74034109, 0.74657287, 0.75021712]),
#  'fit_time': (2.938142776489258, 3.059800148010254, 3.6214334964752197),
#  'test_time': (0.19248223304748535, 0.2352128028869629, 0.1545553207397461)}

# %% [markdown]
# ### Question - 6 - PMF (3 FOLD)

# %%
# Use the famous SVD algorithm.
algo = SVD(biased=False)#PMF

# Run 5-fold cross-validation and print results.
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9667  0.9659  0.9638  0.9655  0.0012
# MAE (testset)     0.7618  0.7611  0.7597  0.7609  0.0009
# Fit time          3.43    3.32    3.06    3.27    0.15
# Test time         0.17    0.17    0.16    0.17    0.00
# {'test_rmse': array([0.96667958, 0.96590291, 0.96382375]),
#  'test_mae': array([0.76180375, 0.76110235, 0.75970218]),
#  'fit_time': (3.4265170097351074, 3.317866086959839, 3.060387134552002),
#  'test_time': (0.1695692539215088, 0.17057228088378906, 0.16353082656860352)}

# %% [markdown]
# ### Question - 7 - NMF (3 FOLD)

# %%
# Use the famous SVD algorithm.
algo = NMF()

# Run 5-fold cross-validation and print results.
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm NMF on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9751  0.9795  0.9696  0.9747  0.0041
# MAE (testset)     0.7661  0.7703  0.7614  0.7659  0.0036
# Fit time          2.91    3.04    3.13    3.03    0.09
# Test time         0.16    0.15    0.16    0.16    0.00
# {'test_rmse': array([0.97512276, 0.97950082, 0.96958683]),
#  'test_mae': array([0.76613197, 0.77030761, 0.76138594]),
#  'fit_time': (2.9112143516540527, 3.0448598861694336, 3.1269195079803467),
#  'test_time': (0.15957093238830566, 0.15259027481079102, 0.1575760841369629)}

# %% [markdown]
# ### Question - 8 - USER BASED COLLABORATIVE FILTERING ALGORITHM (3 FOLD)

# %%
# Use the famous SVD algorithm.
algo = KNNBasic(sim_options={
    'user_based':True
})

# Run 5-fold cross-validation and print results.
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9851  0.9906  0.9901  0.9886  0.0025
# MAE (testset)     0.7782  0.7835  0.7819  0.7812  0.0023
# Fit time          0.26    0.26    0.25    0.26    0.00
# Test time         3.36    3.39    3.47    3.41    0.05
# {'test_rmse': array([0.98514425, 0.99064024, 0.99008313]),
#  'test_mae': array([0.7781536 , 0.78353295, 0.78190401]),
#  'fit_time': (0.26326465606689453, 0.2553226947784424, 0.25431156158447266),
#  'test_time': (3.3581840991973877, 3.3880038261413574, 3.4697153568267822)}

# %% [markdown]
# ### Question - 9 - ITEM BASED COLLABORATIVE FILTERING ALGORITHM (3 FOLD)

# %%
# Use the famous SVD algorithm.
algo = KNNBasic(sim_options={
    'user_based':False
})

# Run 5-fold cross-validation and print results.
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9912  0.9852  0.9823  0.9862  0.0037
# MAE (testset)     0.7857  0.7819  0.7756  0.7811  0.0042
# Fit time          0.37    0.37    0.37    0.37    0.00
# Test time         4.05    4.14    3.77    3.98    0.16
# {'test_rmse': array([0.99120948, 0.98519571, 0.98227595]),
#  'test_mae': array([0.78573768, 0.78186821, 0.77563221]),
#  'fit_time': (0.3699793815612793, 0.36901259422302246, 0.37100720405578613),
#  'test_time': (4.0474464893341064, 4.138998031616211, 3.766930341720581)}

# %% [markdown]
# ### Question - 10,11,12 -Performance of USER/ITEM,PMF,SVD,NMF on Each Fold Respectively

# %%
kf = KFold(n_splits=3)


i=0
for trainset, testset in kf.split(data):
    i+=1
    if(i==1):
        print("Fold - 1")
        print("*"*50)
        print("SVD")
        algo_svd = SVD()
        # train and test algorithm.
        algo_svd.fit(trainset)
        predictions_svd = algo_svd.test(testset)
        # Compute and print Root Mean Squared Error
        accuracy.rmse(predictions_svd, verbose=True)
        accuracy.mae(predictions_svd, verbose=True)
        print("*"*50)
        print("PMF")
        algo_PMF = SVD(biased=False)
        # train and test algorithm.
        algo_PMF.fit(trainset)
        predictions_PMF = algo_PMF.test(testset)
        # Compute and print Root Mean Squared Error
        accuracy.rmse(predictions_PMF, verbose=True)
        accuracy.mae(predictions_PMF, verbose=True)
        print("*"*50)
        print("NMF")
        algo_NMF = NMF(biased=False)
        # train and test algorithm.
        algo_NMF.fit(trainset)
        predictions_NMF = algo_NMF.test(testset)
        # Compute and print Root Mean Squared Error
        accuracy.rmse(predictions_NMF, verbose=True)
        accuracy.mae(predictions_NMF, verbose=True)
        print("*"*50)
        print("User Based Collaborative Filtering")
        algo_UC =  KNNBasic(sim_options={
        'user_based':True
        })
        # train and test algorithm.
        algo_UC.fit(trainset)
        predictions_UC = algo_UC.test(testset)
        # Compute and print Root Mean Squared Error
        accuracy.rmse(predictions_UC, verbose=True)
        accuracy.mae(predictions_UC, verbose=True)
        print("*"*50)
        print("Item Based Collaborative Filtering")
        algo_IC =  KNNBasic(sim_options={
        'user_based':False
        })
        # train and test algorithm.
        algo_IC.fit(trainset)
        predictions_IC = algo_IC.test(testset)
        # Compute and print Root Mean Squared Error
        accuracy.rmse(predictions_IC, verbose=True)
        accuracy.mae(predictions_IC, verbose=True)
        print("*"*50)
    print("#"*50)
    if(i==2):
        print("Fold - 2")
        print("*"*50)
        print("SVD")
        algo_svd = SVD()
        # train and test algorithm.
        algo_svd.fit(trainset)
        predictions_svd = algo_svd.test(testset)
        # Compute and print Root Mean Squared Error
        accuracy.rmse(predictions_svd, verbose=True)
        accuracy.mae(predictions_svd, verbose=True)
        print("*"*50)
        print("PMF")
        algo_PMF = SVD(biased=False)
        # train and test algorithm.
        algo_PMF.fit(trainset)
        predictions_PMF = algo_PMF.test(testset)
        # Compute and print Root Mean Squared Error
        accuracy.rmse(predictions_PMF, verbose=True)
        accuracy.mae(predictions_PMF, verbose=True)
        print("*"*50)
        print("NMF")
        algo_NMF = NMF(biased=False)
        # train and test algorithm.
        algo_NMF.fit(trainset)
        predictions_NMF = algo_NMF.test(testset)
        # Compute and print Root Mean Squared Error
        accuracy.rmse(predictions_NMF, verbose=True)
        accuracy.mae(predictions_NMF, verbose=True)
        print("*"*50)
        print("User Based Collaborative Filtering")
        algo_UC =  KNNBasic(sim_options={
        'user_based':True
        })
        # train and test algorithm.
        algo_UC.fit(trainset)
        predictions_UC = algo_UC.test(testset)
        # Compute and print Root Mean Squared Error
        accuracy.rmse(predictions_UC, verbose=True)
        accuracy.mae(predictions_UC, verbose=True)
        print("*"*50)
        print("Item Based Collaborative Filtering")
        algo_IC =  KNNBasic(sim_options={
        'user_based':False
        })
        # train and test algorithm.
        algo_IC.fit(trainset)
        predictions_IC = algo_IC.test(testset)
        # Compute and print Root Mean Squared Error
        accuracy.rmse(predictions_IC, verbose=True)
        accuracy.mae(predictions_IC, verbose=True)
        print("*"*50)
    print("#"*50)
    if(i==3):
        print("Fold - 3")
        print("*"*50)
        print("SVD")
        algo_svd = SVD()
        # train and test algorithm.
        algo_svd.fit(trainset)
        predictions_svd = algo_svd.test(testset)
        # Compute and print Root Mean Squared Error
        accuracy.rmse(predictions_svd, verbose=True)
        accuracy.mae(predictions_svd, verbose=True)
        print("*"*50)
        print("PMF")
        algo_PMF = SVD(biased=False)
        # train and test algorithm.
        algo_PMF.fit(trainset)
        predictions_PMF = algo_PMF.test(testset)
        # Compute and print Root Mean Squared Error
        accuracy.rmse(predictions_PMF, verbose=True)
        accuracy.mae(predictions_PMF, verbose=True)
        print("*"*50)
        print("NMF")
        algo_NMF = NMF(biased=False)
        # train and test algorithm.
        algo_NMF.fit(trainset)
        predictions_NMF = algo_NMF.test(testset)
        # Compute and print Root Mean Squared Error
        accuracy.rmse(predictions_NMF, verbose=True)
        accuracy.mae(predictions_NMF, verbose=True)
        print("*"*50)
        print("User Based Collaborative Filtering")
        algo_UC =  KNNBasic(sim_options={
        'user_based':True
        })
        # train and test algorithm.
        algo_UC.fit(trainset)
        predictions_UC = algo_UC.test(testset)
        # Compute and print Root Mean Squared Error
        accuracy.rmse(predictions_UC, verbose=True)
        accuracy.mae(predictions_UC, verbose=True)
        print("*"*50)
        print("Item Based Collaborative Filtering")
        algo_IC =  KNNBasic(sim_options={
        'user_based':False
        })
        # train and test algorithm.
        algo_IC.fit(trainset)
        predictions_IC = algo_IC.test(testset)
        # Compute and print Root Mean Squared Error
        accuracy.rmse(predictions_IC, verbose=True)
        accuracy.mae(predictions_IC, verbose=True)
        print("*"*50)
# Out:
# Fold - 1
# **************************************************
# SVD
# RMSE: 0.9442
# MAE:  0.7457
# **************************************************
# PMF
# RMSE: 0.9645
# MAE:  0.7610
# **************************************************
# NMF
# RMSE: 0.9794
# MAE:  0.7694
# **************************************************
# User Based Collaborative Filtering
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9912
# MAE:  0.7839
# **************************************************
# Item Based Collaborative Filtering
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9874
# MAE:  0.7820
# **************************************************
# ##################################################
# ##################################################
# ##################################################
# Fold - 2
# **************************************************
# SVD
# RMSE: 0.9418
# MAE:  0.7439
# **************************************************
# PMF
# RMSE: 0.9684
# MAE:  0.7626
# **************************************************
# NMF
# RMSE: 0.9673
# MAE:  0.7594
# **************************************************
# User Based Collaborative Filtering
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9844
# MAE:  0.7779
# **************************************************
# Item Based Collaborative Filtering
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9830
# MAE:  0.7795
# **************************************************
# ##################################################
# ##################################################
# ##################################################
# Fold - 3
# **************************************************
# SVD
# RMSE: 0.9475
# MAE:  0.7470
# **************************************************
# PMF
# RMSE: 0.9661
# MAE:  0.7632
# **************************************************
# NMF
# RMSE: 0.9723
# MAE:  0.7643
# **************************************************
# User Based Collaborative Filtering
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9907
# MAE:  0.7822
# **************************************************
# Item Based Collaborative Filtering
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9879
# MAE:  0.7821
# **************************************************

# %% [markdown]
# ### Question - 13- average (mean) performances of User-based collaborative filtering, itembased collaborative filtering, SVD, PMF, NMF with respect to RMSE and MAE

# %%
algo = SVD()

# Run 5-fold cross-validation and print results.
svd=cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)

# Use the famous SVD algorithm.
algo = SVD(biased=False)#PMF

# Run 5-fold cross-validation and print results.
pmf=cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Use the famous SVD algorithm.
algo = NMF()

# Run 5-fold cross-validation and print results.
nmf=cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)

# Use the famous SVD algorithm.
algo = KNNBasic(sim_options={
    'user_based':True
})

# Run 5-fold cross-validation and print results.
ub=cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)

# Use the famous SVD algorithm.
algo = KNNBasic(sim_options={
    'user_based':False
})

# Run 5-fold cross-validation and print results.
ib=cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
print("Average mean Performance of SVD")
print("MAE"+str(svd['test_mae'].mean()))
print("RMSE"+str(svd['test_rmse'].mean()))
print("*"*25)
print("Average mean Performance of PMF")
print("MAE"+str(pmf['test_mae'].mean()))
print("RMSE"+str(pmf['test_rmse'].mean()))
print("*"*25)
print("Average mean Performance of NMF")
print("MAE"+str(nmf['test_mae'].mean()))
print("RMSE"+str(nmf['test_rmse'].mean()))
print("*"*25)
print("Average mean Performance of USER BASED")
print("MAE"+str(ub['test_mae'].mean()))
print("RMSE"+str(ub['test_rmse'].mean()))
print("*"*25)
print("Average mean Performance of ITEM BASED")
print("MAE"+str(ib['test_mae'].mean()))
print("RMSE"+str(ib['test_rmse'].mean()))
print("*"*25)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9413  0.9452  0.9501  0.9455  0.0036
# MAE (testset)     0.7446  0.7474  0.7481  0.7467  0.0015
# Fit time          2.94    3.13    2.94    3.00    0.09
# Test time         0.15    0.23    0.15    0.18    0.04
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9747  0.9615  0.9618  0.9660  0.0062
# MAE (testset)     0.7673  0.7578  0.7581  0.7611  0.0044
# Fit time          2.95    2.98    3.30    3.08    0.16
# Test time         0.20    0.14    0.15    0.16    0.03
# Evaluating RMSE, MAE of algorithm NMF on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9742  0.9773  0.9727  0.9747  0.0019
# MAE (testset)     0.7659  0.7679  0.7653  0.7664  0.0011
# Fit time          2.95    3.33    3.38    3.22    0.19
# Test time         0.19    0.16    0.19    0.18    0.01
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9901  0.9846  0.9935  0.9894  0.0036
# MAE (testset)     0.7835  0.7777  0.7834  0.7815  0.0027
# Fit time          0.27    0.25    0.25    0.26    0.01
# Test time         3.65    3.64    3.45    3.58    0.09
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9839  0.9890  0.9847  0.9859  0.0023
# MAE (testset)     0.7808  0.7837  0.7793  0.7813  0.0018
# Fit time          0.37    0.39    0.37    0.38    0.01
# Test time         3.84    4.17    3.86    3.96    0.15
# Average mean Performance of SVD
# MAE0.7467112810896451
# RMSE0.9455354153666001
# *************************
# Average mean Performance of PMF
# MAE0.7610663918262226
# RMSE0.9660122518509469
# *************************
# Average mean Performance of NMF
# MAE0.7663903323466368
# RMSE0.9747357767633792
# *************************
# Average mean Performance of USER BASED
# MAE0.7815383901080648
# RMSE0.9893924221549167
# *************************
# Average mean Performance of ITEM BASED
# MAE0.781260510161259
# RMSE0.9858806855513599
# *************************

# %% [markdown]
# ### Question - 14- MSD,COSINE,PEARSON impact on User and ITEM Based Collaborative Filtering

# %% [markdown]
# #### User Based

# %%
print("User based Colloborative Filtering")
print("*"*25)
print("MSD")
print("*"*25)
algo = KNNBasic(sim_options = {
        'name': 'MSD',
        'user_based': True 
        })
User_based_value_MSD=cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)

#User-based collaborative filtering. Cosine

print("*"*25)
print("Cosine")
print("*"*25)
algo = KNNBasic(sim_options = {
        'name': 'cosine',
        'user_based': True 
        })
User_based_value_Cosine=cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
#User-based collaborative filtering. Pearson.

print("*"*25)
print("Pearson")
print("*"*25)
algo = KNNBasic(sim_options = {
        'name': 'pearson',
        'user_based': True 
        })
User_based_values_Pearson=cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# User based Colloborative Filtering
# *************************
# MSD
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9847  0.9932  0.9844  0.9875  0.0041
# MAE (testset)     0.7781  0.7828  0.7793  0.7801  0.0020
# Fit time          0.25    0.28    0.26    0.26    0.01
# Test time         3.43    3.61    3.39    3.47    0.10
# *************************
# Cosine
# *************************
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0178  1.0251  1.0215  1.0215  0.0030
# MAE (testset)     0.8078  0.8107  0.8078  0.8088  0.0014
# Fit time          0.95    0.95    0.99    0.96    0.02
# Test time         3.50    3.37    4.56    3.81    0.53
# *************************
# Pearson
# *************************
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0263  1.0170  1.0170  1.0201  0.0044
# MAE (testset)     0.8154  0.8066  0.8063  0.8094  0.0042
# Fit time          1.22    1.25    1.25    1.24    0.02
# Test time         3.36    3.81    3.44    3.54    0.20

# %% [markdown]
# #### Item Based

# %%
print("Item based Colloborative Filtering")
print("*"*25)
print("MSD")
print("*"*25)
algo = KNNBasic(sim_options = {
        'name': 'MSD',
        'user_based': False 
        })
item_based_values_MSD=cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)

#User-based collaborative filtering. Cosine

print("*"*25)
print("Cosine")
print("*"*25)
algo = KNNBasic(sim_options = {
        'name': 'cosine',
        'user_based': False 
        })
item_based_values_cosine=cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)#User-based collaborative filtering. Pearson.

print("*"*25)
print("Pearson")
print("*"*25)
algo = KNNBasic(sim_options = {
        'name': 'pearson',
        'user_based': False 
        })
item_based_values_pearson=cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# Item based Colloborative Filtering
# *************************
# MSD
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9843  0.9914  0.9802  0.9853  0.0046
# MAE (testset)     0.7768  0.7862  0.7780  0.7803  0.0042
# Fit time          0.38    0.38    0.37    0.38    0.01
# Test time         3.84    4.55    5.02    4.47    0.48
# *************************
# Cosine
# *************************
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0381  1.0379  1.0356  1.0372  0.0011
# MAE (testset)     0.8239  0.8254  0.8219  0.8237  0.0015
# Fit time          1.42    1.53    1.49    1.48    0.04
# Test time         3.82    5.62    3.92    4.45    0.82
# *************************
# Pearson
# *************************
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0488  1.0434  1.0515  1.0479  0.0033
# MAE (testset)     0.8386  0.8349  0.8412  0.8382  0.0026
# Fit time          1.88    1.89    2.48    2.08    0.28
# Test time         3.82    4.13    3.90    3.95    0.13

# %%
item_based_values_pearson['test_rmse']
# Out:
# array([1.04877927, 1.0434253 , 1.05148365])

# %%
metrics = np.array(['MSD', 'cosine', 'pearson'])
values=[item_based_values_MSD['test_mae'].mean(), item_based_values_cosine['test_mae'].mean(), item_based_values_pearson['test_mae'].mean()]
series = pd.Series(name='MAE', data=values)
ax = sns.barplot(metrics, series.values)
ax.set_title("Similarity Metrics Comparison: Item Based- MAE")
ax.set_ylabel('MAE values')
ax.set_xlabel('Metrics')
ax.set_ylim(.7, 0.9)
plt.show()
metrics = np.array(['MSD', 'cosine', 'pearson'])
values=[item_based_values_MSD['test_rmse'].mean(), item_based_values_cosine['test_rmse'].mean(), item_based_values_pearson['test_rmse'].mean()]
series = pd.Series(name='RMSE', data=values)
ax = sns.barplot(metrics, series.values)
ax.set_title("Similarity Metrics Comparison: Item Based- RMSE")
ax.set_ylabel('RMSE values')
ax.set_xlabel('Metrics')
ax.set_ylim(.95, 1.1)
plt.show()

# %%
metrics = np.array(['MSD', 'cosine', 'pearson'])
values=[User_based_value_MSD['test_mae'].mean(), User_based_value_Cosine['test_mae'].mean(), User_based_values_Pearson['test_mae'].mean()]
series = pd.Series(name='MAE', data=values)
ax = sns.barplot(metrics, series.values)
ax.set_title("Similarity Metrics Comparison: User Based- MAE")
ax.set_ylabel('MAE values')
ax.set_xlabel('Metrics')
ax.set_ylim(.7, 0.9)
plt.show()
metrics = np.array(['MSD', 'cosine', 'pearson'])
values=[User_based_value_MSD['test_rmse'].mean(), User_based_value_Cosine['test_rmse'].mean(), User_based_values_Pearson['test_rmse'].mean()]
series = pd.Series(name='RMSE', data=values)
ax = sns.barplot(metrics, series.values)
ax.set_title("Similarity Metrics Comparison: User Based- RMSE")
ax.set_ylabel('RMSE values')
ax.set_xlabel('Metrics')
ax.set_ylim(.95, 1.1)
plt.show()

# %%
print("User based Colloborative Filtering")
print("*"*25)
mean_rmse=[]
for i in range(0,30):
    print("*"*25)
    print("K value is "+str(i))
    print("*"*25)
    algo = KNNBasic( k=i,sim_options = {
            'name': 'MSD',
            'user_based': True 
            })
    User_based_value_k=cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
    mean_rmse.append(User_based_value_k['test_rmse'].mean())
# Out:
# User based Colloborative Filtering
# *************************
# *************************
# K value is 0
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.1214  1.1274  1.1283  1.1257  0.0031
# MAE (testset)     0.9404  0.9470  0.9467  0.9447  0.0031
# Fit time          0.41    0.43    0.33    0.39    0.05
# Test time         1.73    1.96    1.76    1.81    0.10
# *************************
# K value is 1
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.3306  1.3187  1.3176  1.3223  0.0059
# MAE (testset)     0.9831  0.9731  0.9734  0.9765  0.0046
# Fit time          0.25    0.27    0.26    0.26    0.01
# Test time         1.97    1.84    1.68    1.83    0.12
# *************************
# K value is 2
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.1580  1.1487  1.1583  1.1550  0.0044
# MAE (testset)     0.8966  0.8884  0.8942  0.8931  0.0035
# Fit time          0.26    0.27    0.27    0.26    0.01
# Test time         1.89    1.85    1.99    1.91    0.06
# *************************
# K value is 3
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0838  1.0907  1.0908  1.0884  0.0033
# MAE (testset)     0.8465  0.8523  0.8499  0.8496  0.0024
# Fit time          0.26    0.27    0.27    0.27    0.00
# Test time         1.98    1.98    2.06    2.01    0.04
# *************************
# K value is 4
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0565  1.0654  1.0560  1.0593  0.0043
# MAE (testset)     0.8315  0.8352  0.8270  0.8312  0.0033
# Fit time          0.27    0.26    0.26    0.27    0.01
# Test time         1.94    2.06    1.96    1.99    0.05
# *************************
# K value is 5
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0279  1.0439  1.0360  1.0359  0.0065
# MAE (testset)     0.8097  0.8217  0.8145  0.8153  0.0049
# Fit time          0.25    0.26    0.29    0.26    0.02
# Test time         2.20    2.13    2.20    2.18    0.03
# *************************
# K value is 6
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0194  1.0305  1.0211  1.0237  0.0049
# MAE (testset)     0.8032  0.8111  0.8034  0.8059  0.0036
# Fit time          0.25    0.26    0.26    0.25    0.00
# Test time         2.11    2.09    2.17    2.12    0.03
# *************************
# K value is 7
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0128  1.0221  1.0151  1.0167  0.0040
# MAE (testset)     0.7970  0.8065  0.7997  0.8011  0.0040
# Fit time          0.25    0.26    0.26    0.25    0.01
# Test time         2.11    2.14    2.39    2.21    0.12
# *************************
# K value is 8
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0135  1.0031  1.0075  1.0080  0.0043
# MAE (testset)     0.8007  0.7911  0.7927  0.7948  0.0042
# Fit time          0.26    0.26    0.26    0.26    0.00
# Test time         2.14    2.30    2.20    2.21    0.07
# *************************
# K value is 9
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0087  0.9988  1.0040  1.0038  0.0041
# MAE (testset)     0.7953  0.7880  0.7908  0.7914  0.0030
# Fit time          0.25    0.26    0.29    0.27    0.02
# Test time         2.31    2.27    2.36    2.31    0.03
# *************************
# K value is 10
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0005  1.0048  0.9997  1.0016  0.0022
# MAE (testset)     0.7891  0.7908  0.7893  0.7897  0.0008
# Fit time          0.26    0.26    0.30    0.28    0.02
# Test time         2.37    2.28    2.39    2.34    0.05
# *************************
# K value is 11
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9940  0.9993  0.9978  0.9970  0.0023
# MAE (testset)     0.7843  0.7888  0.7842  0.7858  0.0022
# Fit time          0.25    0.26    0.26    0.25    0.01
# Test time         2.33    2.54    2.78    2.55    0.19
# *************************
# K value is 12
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9956  0.9961  0.9946  0.9954  0.0006
# MAE (testset)     0.7866  0.7857  0.7836  0.7853  0.0013
# Fit time          0.27    0.26    0.26    0.26    0.01
# Test time         2.59    2.50    2.46    2.52    0.06
# *************************
# K value is 13
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9962  0.9898  0.9902  0.9921  0.0029
# MAE (testset)     0.7844  0.7828  0.7795  0.7822  0.0021
# Fit time          0.24    0.26    0.27    0.26    0.01
# Test time         2.47    2.52    2.88    2.62    0.18
# *************************
# K value is 14
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9976  0.9906  0.9867  0.9916  0.0045
# MAE (testset)     0.7863  0.7814  0.7783  0.7820  0.0033
# Fit time          0.27    0.26    0.26    0.26    0.00
# Test time         2.59    2.73    2.56    2.63    0.08
# *************************
# K value is 15
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9837  0.9930  0.9925  0.9897  0.0043
# MAE (testset)     0.7761  0.7848  0.7817  0.7808  0.0036
# Fit time          0.26    0.26    0.26    0.26    0.00
# Test time         2.51    2.77    2.67    2.65    0.11
# *************************
# K value is 16
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9902  0.9851  0.9914  0.9889  0.0027
# MAE (testset)     0.7797  0.7782  0.7822  0.7800  0.0017
# Fit time          0.24    0.28    0.26    0.26    0.01
# Test time         3.76    2.66    2.67    3.03    0.52
# *************************
# K value is 17
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9906  0.9873  0.9888  0.9889  0.0013
# MAE (testset)     0.7828  0.7771  0.7804  0.7801  0.0023
# Fit time          0.26    0.26    0.26    0.26    0.00
# Test time         3.81    2.86    2.79    3.15    0.47
# *************************
# K value is 18
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9833  0.9963  0.9808  0.9868  0.0068
# MAE (testset)     0.7757  0.7862  0.7743  0.7787  0.0053
# Fit time          0.25    0.28    0.27    0.26    0.01
# Test time         2.84    2.91    2.88    2.88    0.03
# *************************
# K value is 19
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9906  0.9869  0.9827  0.9867  0.0032
# MAE (testset)     0.7829  0.7794  0.7747  0.7790  0.0034
# Fit time          0.25    0.25    0.26    0.25    0.00
# Test time         2.69    2.77    2.84    2.77    0.06
# *************************
# K value is 20
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9870  0.9891  0.9807  0.9856  0.0036
# MAE (testset)     0.7782  0.7794  0.7750  0.7776  0.0019
# Fit time          0.25    0.27    0.26    0.26    0.01
# Test time         2.81    2.79    2.75    2.78    0.03
# *************************
# K value is 21
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9821  0.9890  0.9856  0.9855  0.0028
# MAE (testset)     0.7779  0.7796  0.7760  0.7778  0.0015
# Fit time          0.26    0.26    0.26    0.26    0.00
# Test time         2.74    2.84    3.02    2.87    0.12
# *************************
# K value is 22
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9818  0.9903  0.9891  0.9871  0.0038
# MAE (testset)     0.7750  0.7818  0.7793  0.7787  0.0028
# Fit time          0.27    0.25    0.35    0.29    0.04
# Test time         3.73    3.34    3.41    3.50    0.17
# *************************
# K value is 23
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9862  0.9818  0.9917  0.9865  0.0041
# MAE (testset)     0.7796  0.7742  0.7828  0.7789  0.0035
# Fit time          0.25    0.27    0.26    0.26    0.01
# Test time         3.03    4.37    3.95    3.79    0.56
# *************************
# K value is 24
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9887  0.9846  0.9896  0.9876  0.0022
# MAE (testset)     0.7788  0.7772  0.7814  0.7791  0.0017
# Fit time          0.38    0.33    0.28    0.33    0.04
# Test time         4.48    3.55    3.16    3.73    0.55
# *************************
# K value is 25
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9876  0.9799  0.9907  0.9861  0.0046
# MAE (testset)     0.7793  0.7733  0.7817  0.7781  0.0036
# Fit time          0.26    0.26    0.26    0.26    0.00
# Test time         2.98    2.94    3.22    3.05    0.12
# *************************
# K value is 26
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9858  0.9892  0.9846  0.9866  0.0020
# MAE (testset)     0.7796  0.7802  0.7766  0.7788  0.0016
# Fit time          0.32    0.25    0.28    0.28    0.03
# Test time         3.22    3.94    3.02    3.39    0.40
# *************************
# K value is 27
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9843  0.9881  0.9883  0.9869  0.0019
# MAE (testset)     0.7768  0.7812  0.7801  0.7793  0.0019
# Fit time          0.25    0.29    0.26    0.27    0.02
# Test time         2.96    3.12    2.99    3.02    0.07
# *************************
# K value is 28
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9873  0.9880  0.9846  0.9866  0.0015
# MAE (testset)     0.7788  0.7814  0.7780  0.7794  0.0015
# Fit time          0.25    0.25    0.25    0.25    0.00
# Test time         2.97    3.12    4.42    3.50    0.65
# *************************
# K value is 29
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9892  0.9829  0.9834  0.9852  0.0028
# MAE (testset)     0.7814  0.7751  0.7782  0.7782  0.0026
# Fit time          0.91    0.56    0.46    0.64    0.19
# Test time         7.25    5.42    3.78    5.48    1.42

# %%
len(mean_rmse)
min(mean_rmse)
#np.argmin(mean_rmse)
# Out:
# 0.9860042098619242

# %%
K = [i for i in range(30)]
series = pd.Series(name='RMSE', data=mean_rmse)
ax = sns.barplot(K, series.values)
ax.set_title("Similarity Metrics Comparison: User Based- RMSE")
ax.set_ylabel('RMSE values')
ax.set_xlabel('Metrics')
ax.set_ylim(.985, 0.9875)
plt.show()

# %%
print("Item based Colloborative Filtering")
print("*"*25)
mean_rmse=[]
for i in range(0,30):
    print("*"*25)
    print("K value is "+str(i))
    print("*"*25)
    algo = KNNBasic( k=i,sim_options = {
            'name': 'MSD',
            'user_based': False 
            })
    Item_based_value_k=cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
    mean_rmse.append(Item_based_value_k['test_rmse'].mean())
# Out:
# Item based Colloborative Filtering
# *************************
# *************************
# K value is 0
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.1238  1.1232  1.1300  1.1257  0.0031
# MAE (testset)     0.9424  0.9425  0.9492  0.9447  0.0031
# Fit time          0.41    0.53    0.42    0.46    0.06
# Test time         1.77    1.62    2.23    1.87    0.26
# *************************
# K value is 1
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.4367  1.4343  1.4292  1.4334  0.0031
# MAE (testset)     1.0628  1.0593  1.0554  1.0592  0.0030
# Fit time          0.44    0.43    0.37    0.41    0.03
# Test time         2.10    2.20    2.40    2.23    0.13
# *************************
# K value is 2
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.2331  1.2405  1.2285  1.2341  0.0050
# MAE (testset)     0.9514  0.9579  0.9478  0.9524  0.0042
# Fit time          0.36    0.37    0.40    0.38    0.02
# Test time         2.15    2.44    2.56    2.38    0.17
# *************************
# K value is 3
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.1599  1.1561  1.1530  1.1563  0.0028
# MAE (testset)     0.9071  0.9039  0.9000  0.9037  0.0029
# Fit time          0.51    0.40    0.40    0.44    0.05
# Test time         2.43    2.45    2.72    2.53    0.13
# *************************
# K value is 4
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.1131  1.1083  1.1117  1.1110  0.0020
# MAE (testset)     0.8740  0.8715  0.8716  0.8724  0.0012
# Fit time          0.50    0.45    0.38    0.44    0.05
# Test time         2.64    4.33    2.76    3.24    0.77
# *************************
# K value is 5
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0783  1.0879  1.0827  1.0830  0.0039
# MAE (testset)     0.8494  0.8567  0.8540  0.8534  0.0030
# Fit time          0.47    0.48    0.46    0.47    0.01
# Test time         2.87    3.28    2.73    2.96    0.23
# *************************
# K value is 6
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0645  1.0681  1.0590  1.0638  0.0037
# MAE (testset)     0.8399  0.8426  0.8379  0.8401  0.0019
# Fit time          0.44    0.49    0.45    0.46    0.02
# Test time         3.21    3.87    2.47    3.18    0.57
# *************************
# K value is 7
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0467  1.0431  1.0566  1.0488  0.0057
# MAE (testset)     0.8255  0.8229  0.8333  0.8272  0.0044
# Fit time          0.36    0.37    0.39    0.37    0.01
# Test time         3.19    3.78    3.27    3.42    0.26
# *************************
# K value is 8
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0403  1.0330  1.0464  1.0399  0.0055
# MAE (testset)     0.8218  0.8158  0.8276  0.8217  0.0048
# Fit time          0.36    0.39    0.40    0.39    0.01
# Test time         3.18    3.93    3.63    3.58    0.31
# *************************
# K value is 9
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0299  1.0254  1.0353  1.0302  0.0041
# MAE (testset)     0.8137  0.8115  0.8178  0.8143  0.0026
# Fit time          0.42    0.60    0.38    0.47    0.09
# Test time         2.80    3.30    2.90    3.00    0.22
# *************************
# K value is 10
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0234  1.0222  1.0285  1.0247  0.0027
# MAE (testset)     0.8101  0.8066  0.8135  0.8101  0.0028
# Fit time          0.56    0.48    0.40    0.48    0.06
# Test time         3.50    4.17    3.28    3.65    0.38
# *************************
# K value is 11
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0179  1.0186  1.0183  1.0183  0.0003
# MAE (testset)     0.8063  0.8064  0.8059  0.8062  0.0002
# Fit time          0.36    0.39    0.42    0.39    0.02
# Test time         2.94    3.01    3.02    2.99    0.03
# *************************
# K value is 12
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0157  1.0133  1.0109  1.0133  0.0019
# MAE (testset)     0.8034  0.8037  0.7994  0.8022  0.0020
# Fit time          0.40    0.60    0.42    0.47    0.09
# Test time         3.87    3.41    3.90    3.73    0.22
# *************************
# K value is 13
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0093  1.0071  1.0109  1.0091  0.0016
# MAE (testset)     0.7984  0.7969  0.7989  0.7981  0.0008
# Fit time          0.44    0.57    0.50    0.51    0.05
# Test time         3.25    3.65    3.70    3.53    0.20
# *************************
# K value is 14
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0071  1.0007  1.0078  1.0052  0.0032
# MAE (testset)     0.7974  0.7934  0.7956  0.7955  0.0017
# Fit time          0.42    0.48    0.57    0.49    0.06
# Test time         4.15    3.55    3.97    3.89    0.25
# *************************
# K value is 15
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0003  1.0038  1.0061  1.0034  0.0024
# MAE (testset)     0.7907  0.7954  0.7964  0.7942  0.0025
# Fit time          0.45    0.52    0.47    0.48    0.03
# Test time         3.55    3.89    3.63    3.69    0.15
# *************************
# K value is 16
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0067  1.0010  0.9968  1.0015  0.0040
# MAE (testset)     0.7955  0.7934  0.7880  0.7923  0.0032
# Fit time          0.47    0.48    0.55    0.50    0.03
# Test time         3.50    3.73    3.92    3.72    0.17
# *************************
# K value is 17
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.0025  0.9970  1.0003  0.9999  0.0023
# MAE (testset)     0.7937  0.7892  0.7910  0.7913  0.0018
# Fit time          0.48    0.48    0.44    0.46    0.02
# Test time         4.12    3.77    4.14    4.01    0.17
# *************************
# K value is 18
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9974  0.9948  0.9993  0.9972  0.0018
# MAE (testset)     0.7886  0.7879  0.7917  0.7894  0.0017
# Fit time          0.45    0.47    0.48    0.47    0.01
# Test time         3.74    3.77    3.70    3.74    0.03
# *************************
# K value is 19
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9932  0.9931  0.9947  0.9937  0.0007
# MAE (testset)     0.7864  0.7864  0.7883  0.7870  0.0009
# Fit time          0.46    0.48    0.47    0.47    0.01
# Test time         3.74    4.26    4.50    4.17    0.32
# *************************
# K value is 20
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9934  0.9987  0.9930  0.9950  0.0026
# MAE (testset)     0.7871  0.7904  0.7837  0.7871  0.0027
# Fit time          0.52    0.50    0.49    0.50    0.01
# Test time         4.09    3.79    4.09    3.99    0.14
# *************************
# K value is 21
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9969  0.9920  0.9903  0.9931  0.0028
# MAE (testset)     0.7886  0.7856  0.7829  0.7857  0.0023
# Fit time          0.53    0.54    0.59    0.55    0.03
# Test time         4.65    4.86    4.61    4.71    0.11
# *************************
# K value is 22
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9911  0.9876  0.9937  0.9908  0.0025
# MAE (testset)     0.7856  0.7805  0.7847  0.7836  0.0022
# Fit time          0.44    0.46    0.50    0.47    0.02
# Test time         3.64    4.04    4.56    4.08    0.38
# *************************
# K value is 23
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9804  0.9980  0.9929  0.9904  0.0074
# MAE (testset)     0.7760  0.7913  0.7848  0.7841  0.0063
# Fit time          0.47    0.54    0.52    0.51    0.03
# Test time         4.28    4.30    3.71    4.10    0.27
# *************************
# K value is 24
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9873  0.9950  0.9922  0.9915  0.0032
# MAE (testset)     0.7838  0.7849  0.7839  0.7842  0.0005
# Fit time          0.38    0.40    0.42    0.40    0.01
# Test time         3.52    3.63    3.59    3.58    0.04
# *************************
# K value is 25
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9856  0.9948  0.9864  0.9889  0.0042
# MAE (testset)     0.7817  0.7873  0.7785  0.7825  0.0036
# Fit time          0.39    0.49    0.53    0.47    0.06
# Test time         3.47    4.40    4.28    4.05    0.41
# *************************
# K value is 26
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9847  0.9911  0.9902  0.9887  0.0028
# MAE (testset)     0.7804  0.7839  0.7828  0.7824  0.0015
# Fit time          0.45    0.65    0.68    0.59    0.10
# Test time         5.39    4.98    4.26    4.88    0.47
# *************************
# K value is 27
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9863  0.9862  0.9895  0.9873  0.0015
# MAE (testset)     0.7836  0.7782  0.7819  0.7813  0.0022
# Fit time          0.50    0.67    0.60    0.59    0.07
# Test time         5.33    4.73    4.57    4.88    0.33
# *************************
# K value is 28
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9811  0.9881  0.9888  0.9860  0.0035
# MAE (testset)     0.7757  0.7815  0.7828  0.7800  0.0031
# Fit time          0.63    0.49    0.50    0.54    0.07
# Test time         4.72    4.20    4.48    4.47    0.21
# *************************
# K value is 29
# *************************
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.9834  0.9890  0.9923  0.9882  0.0037
# MAE (testset)     0.7788  0.7824  0.7847  0.7820  0.0024
# Fit time          0.38    0.55    0.39    0.44    0.08
# Test time         4.60    4.15    3.83    4.19    0.32

# %%
np.argmin(mean_rmse)
# Out:
# 28

# %%
K = [i for i in range(30)]
series = pd.Series(name='RMSE', data=mean_rmse)
ax = sns.barplot(K, series.values)
ax.set_title("Similarity Metrics Comparison: Item Based- RMSE")
ax.set_ylabel('RMSE values')
ax.set_xlabel('Metrics')
ax.set_ylim(.9858, 0.9875)
plt.show()
